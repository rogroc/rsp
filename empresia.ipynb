# %%
societat = 'neos-surgery'

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.9

# %%
# %%shell
# sudo apt -y update
# sudo apt install -y wget curl unzip
# wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# dpkg -i libu2f-udev_1.1.4-1_all.deb
# wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# dpkg -i google-chrome-stable_current_amd64.deb
#
# wget -N https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/118.0.5993.70/linux64/chromedriver-linux64.zip -P /tmp/
# unzip -o /tmp/chromedriver-linux64.zip -d /tmp/
# chmod +x /tmp/chromedriver-linux64/chromedriver
# mv /tmp/chromedriver-linux64/chromedriver /usr/local/bin/chromedriver
# pip install selenium chromedriver_autoinstaller
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease [18.1 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,399 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,064 kB]
# Hit:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:13 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main Sources [2,268 kB]
# Get:14 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy/main amd64 Packages [1,164 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,334 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,678 kB]
# Fetched 9,157 kB in 4s (2,138 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 40 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# curl is already the newest version (7.81.0-1ubuntu1.15).
# unzip is already the newest version (6.0-26ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
# --2024-02-05 07:44:36--  http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 91.189.91.82, 185.125.190.39, 91.189.91.83, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|91.189.91.82|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3708 (3.6K) [application/vnd.debian.binary-package]
# Saving to: ‘libu2f-udev_1.1.4-1_all.deb’
#
# libu2f-udev_1.1.4-1 100%[===================>]   3.62K  --.-KB/s    in 0s
#
# 2024-02-05 07:44:36 (443 MB/s) - ‘libu2f-udev_1.1.4-1_all.deb’ saved [3708/3708]
#
# Selecting previously unselected package libu2f-udev.
# (Reading database ... 121730 files and directories currently installed.)
# Preparing to unpack libu2f-udev_1.1.4-1_all.deb ...
# Unpacking libu2f-udev (1.1.4-1) ...
# Setting up libu2f-udev (1.1.4-1) ...
# --2024-02-05 07:44:37--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 108.177.127.93, 108.177.127.91, 108.177.127.136, ...
# Connecting to dl.google.com (dl.google.com)|108.177.127.93|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106447036 (102M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>] 101.52M   301MB/s    in 0.3s
#
# 2024-02-05 07:44:37 (301 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [106447036/106447036]
#
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 121734 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (121.0.6167.139-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libvulkan1; however:
#   Package libvulkan1 is not installed.
#
# dpkg: error processing package google-chrome-stable (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for man-db (2.10.2-1) ...
# Errors were encountered while processing:
#  google-chrome-stable
# --2024-02-05 07:44:50--  https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/118.0.5993.70/linux64/chromedriver-linux64.zip
# Resolving edgedl.me.gvt1.com (edgedl.me.gvt1.com)... 34.104.35.123, 2600:1900:4110:86f::
# Connecting to edgedl.me.gvt1.com (edgedl.me.gvt1.com)|34.104.35.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8269742 (7.9M) [application/octet-stream]
# Saving to: ‘/tmp/chromedriver-linux64.zip’
#
# chromedriver-linux6 100%[===================>]   7.89M  --.-KB/s    in 0.1s
#
# 2024-02-05 07:44:50 (70.0 MB/s) - ‘/tmp/chromedriver-linux64.zip’ saved [8269742/8269742]
#
# Archive:  /tmp/chromedriver-linux64.zip
#   inflating: /tmp/chromedriver-linux64/LICENSE.chromedriver
#   inflating: /tmp/chromedriver-linux64/chromedriver
# Collecting selenium
#   Downloading selenium-4.17.2-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 21.3 MB/s eta 0:00:00
# Collecting chromedriver_autoinstaller
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 28.9 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.11.17)
# Collecting typing_extensions>=4.9.0 (from selenium)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from chromedriver_autoinstaller) (23.2)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.0 MB/s eta 0:00:00
# Installing collected packages: typing_extensions, outcome, h11, chromedriver_autoinstaller, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed chromedriver_autoinstaller-0.6.4 h11-0.14.0 outcome-1.3.0.post0 selenium-4.17.2 trio-0.24.0 trio-websocket-0.11.1 typing_extensions-4.9.0 wsproto-1.2.0

# %%
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

from selenium import webdriver
import chromedriver_autoinstaller

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') # this is must
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chromedriver_autoinstaller.install()

driver = webdriver.Chrome(options=chrome_options)

# %%
import pandas as pd
import numpy as np
import time

# %%
#societat = 'forestal-catalana'

url = "https://www.empresia.es/empresa/"+societat+"/"

driver.get(url)

#while True:
while 'NextEventos' in driver.page_source:
  try:
        element = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR, "#NextEventos > a"))
        )
        element.click()

  except:
    break

# %%
#societat = 'forestal-catalana'

url = "https://www.empresia.es/empresa/"+societat+"/"

time.sleep(10)

driver.get(url)

#while True:
while 'NextEventos' in driver.page_source:
  try:
        element = WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR, "#NextEventos > a"))
        )
        element.click()

  except:
    break

# %%
from bs4 import BeautifulSoup
import re

RM = []

html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

event_contents = soup.find_all('div', {'class': 'event-content'})

for event_content in event_contents:
  link = event_content.find('a', {'class': 'newWin'})
  link = re.search(r"verPub\('(.+?)'", str(link)).group(1)
  full = re.search(r"H\s+(\w+)\s+(\d+)", str(event_content))
  if 'Empresa' in event_content.text:
    actual = "Nom antic o altra societat"
  else:
    actual = "Nom actual"
  RM.append([link, event_content.find_previous('time')['datetime'], " ".join(event_content.text.split()), (full[0] if full != None else full), actual])

# %%
import pandas as pd

pd.DataFrame(RM)
# Out:
#                                                     0           1  \
# 0   https://www.boe.es/borme/dias/2024/02/02/pdfs/...  2024-02-02
# 1   https://www.boe.es/borme/dias/2023/06/30/pdfs/...  2023-06-30
# 2   https://www.boe.es/borme/dias/2022/04/19/pdfs/...  2022-04-19
# 3   https://www.boe.es/borme/dias/2021/03/22/pdfs/...  2021-03-22
# 4   https://www.boe.es/borme/dias/2021/03/22/pdfs/...  2021-03-22
# 5   https://www.boe.es/borme/dias/2021/01/08/pdfs/...  2021-01-08
# 6   https://www.boe.es/borme/dias/2021/01/08/pdfs/...  2021-01-08
# 7   https://www.boe.es/borme/dias/2020/08/26/pdfs/...  2020-08-26
# 8   https://www.boe.es/borme/dias/2020/08/26/pdfs/...  2020-08-26
# 9   http://www.boe.es/borme/dias/2018/03/22/pdfs/B...  2018-03-22
# 10  http://www.boe.es/borme/dias/2015/10/16/pdfs/B...  2015-10-16
# 11  http://www.boe.es/borme/dias/2015/10/16/pdfs/B...  2015-10-16
# 12  http://www.boe.es/borme/dias/2015/03/10/pdfs/B...  2015-03-10
# 13  http://www.boe.es/borme/dias/2014/08/14/pdfs/B...  2014-08-14
# 14  http://www.boe.es/borme/dias/2014/08/14/pdfs/B...  2014-08-14
# 15  http://www.boe.es/borme/dias/2014/03/31/pdfs/B...  2014-03-31
# 16  http://www.boe.es/borme/dias/2014/03/31/pdfs/B...  2014-03-31
# 17  http://www.boe.es/borme/dias/2014/03/31/pdfs/B...  2014-03-31
# 18  http://www.boe.es/borme/dias/2013/07/25/pdfs/B...  2013-07-25
# 19  http://www.boe.es/borme/dias/2013/06/17/pdfs/B...  2013-06-17
# 20  http://www.boe.es/borme/dias/2013/06/17/pdfs/B...  2013-06-17
# 21  http://www.boe.es/borme/dias/2013/06/17/pdfs/B...  2013-06-17
# 22  http://www.boe.es/borme/dias/2012/11/22/pdfs/B...  2012-11-22
# 23  http://www.boe.es/borme/dias/2011/10/31/pdfs/B...  2011-10-31
# 24  http://www.boe.es/borme/dias/2011/08/31/pdfs/B...  2011-08-31
# 25  http://www.boe.es/borme/dias/2011/08/31/pdfs/B...  2011-08-31
# 26  http://www.boe.es/borme/dias/2011/05/30/pdfs/B...  2011-05-30
# 27  http://www.boe.es/borme/dias/2009/09/10/pdfs/B...  2009-09-10
# 28  http://www.boe.es/borme/dias/2009/02/12/pdfs/B...  2009-02-12
# 29  http://www.boe.es/borme/dias/2009/02/12/pdfs/B...  2009-02-12
# 30  http://www.boe.es/borme/dias/2009/02/12/pdfs/B...  2009-02-12
#
#                                                     2           3  \
# 0   Ampliación de capital. El capital social de la...  H SS 22958
# 1   Ampliación de capital. Los socios o accionista...  H SS 22958
# 2   Revocaciones.Publicación en el BORME de los si...  H SS 22958
# 3   Ceses/Dimisiones. Con fecha 9 de marzo de 2021...  H SS 22958
# 4   Nombramientos. Con fecha 9 de marzo de 2021 se...  H SS 22958
# 5   Nombramientos. Con fecha 29 de diciembre de 20...  H SS 22958
# 6   Otros conceptos:MODIFICACION del ARTICULO 18º ...  H SS 22958
# 7   Ampliación de capital. Los socios o accionista...  H SS 22958
# 8   Otros conceptos:Adición de los arts. 15bis y 2...  H SS 22958
# 9   Ampliación de capital. Con fecha 9 de marzo de...  H SS 22958
# 10  Ceses/Dimisiones. Con fecha 6 de octubre de 20...  H SS 22958
# 11  Nombramientos. Con fecha 6 de octubre de 2015 ...  H SS 22958
# 12  Ceses/Dimisiones. Con fecha 2 de marzo de 2015...  H SS 22958
# 13  Ceses/Dimisiones. Con fecha 7 de agosto de 201...  H SS 22958
# 14  Nombramientos. Con fecha 7 de agosto de 2014 s...  H SS 22958
# 15  Reducción de capital. El capital social de la ...  H SS 22958
# 16  Revocaciones.Publicación en el BORME de los si...  H SS 22958
# 17  Nombramientos.Publicación en el BORME de los s...  H SS 22958
# 18  Nombramientos. Con fecha 17 de julio de 2013 s...  H SS 22958
# 19  Ceses/Dimisiones.Publicación en el BORME de lo...  H SS 22958
# 20  Nombramientos. Con fecha 7 de junio de 2013 se...  H SS 22958
# 21  Nombramientos. Con fecha 7 de junio de 2013 se...  H SS 22958
# 22  Nombramientos. Con fecha 9 de noviembre de 201...  H SS 22958
# 23  Depósito de cuentas anuales En septiembre del ...        None
# 24  Ceses/Dimisiones.Publicación en el BORME de lo...  H SS 22958
# 25  Nombramientos.Publicación en el BORME de los s...  H SS 22958
# 26  Depósito de cuentas anuales En abril del 2011 ...        None
# 27  Depósito de cuentas anuales En julio del 2009 ...        None
# 28  Ceses/Dimisiones.Publicación en el BORME de lo...  H SS 22958
# 29  Nombramientos.Publicación en el BORME de los s...  H SS 22958
# 30  Ampliación de capital. El capital social de la...  H SS 22958
#
#                              4
# 0                   Nom actual
# 1                   Nom actual
# 2                   Nom actual
# 3                   Nom actual
# 4                   Nom actual
# 5   Nom antic o altra societat
# 6                   Nom actual
# 7                   Nom actual
# 8                   Nom actual
# 9                   Nom actual
# 10                  Nom actual
# 11                  Nom actual
# 12                  Nom actual
# 13                  Nom actual
# 14                  Nom actual
# 15                  Nom actual
# 16                  Nom actual
# 17                  Nom actual
# 18                  Nom actual
# 19                  Nom actual
# 20                  Nom actual
# 21                  Nom actual
# 22                  Nom actual
# 23                  Nom actual
# 24                  Nom actual
# 25                  Nom actual
# 26                  Nom actual
# 27                  Nom actual
# 28                  Nom actual
# 29                  Nom actual
# 30                  Nom actual

# %%
'''
import pandas as pd
pd.DataFrame(RM).to_excel(societat+'-empresia.xlsx', index=False)
'''
# Out:
# "\nimport pandas as pd\npd.DataFrame(RM).to_excel(societat+'-empresia.xlsx', index=False)\n"

# %%
'''
from google.colab import files
files.download(societat+'-empresia.xlsx')
'''
# Out:
# "\nfrom google.colab import files\nfiles.download(societat+'-empresia.xlsx')\n"

# %%
# buscar el div amb l'identificador 'organigrama'
organigrama_div = soup.find('div', {'id': 'organigrama'})

# buscar tots els elements 'li' dins del div amb l'identificador 'organigrama'

try:
  li_elements = organigrama_div.find_all('li')

  carrecs = []

# obtenir només el primer text de cada element 'li'
  for li in li_elements:
      # obtenir tots els continguts de l'element 'li'
      contents = li.contents

      # obtenir el primer text
      nom = str(contents[1].text).strip()
      carrec = str(contents[3]).strip()

      # imprimir el primer text
      carrecs.append([nom, carrec])

except:
  carrecs = []

# %%
pd.DataFrame(carrecs)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import datetime

avui = datetime.datetime.now()
avui = str(avui).split(" ")[0].replace("-", "")
'''
pd.DataFrame(carrecs).to_excel(avui+" "+societat+'-carrecs-empresia.xlsx', index=False)
'''
# Out:
# '\npd.DataFrame(carrecs).to_excel(avui+" "+societat+\'-carrecs-empresia.xlsx\', index=False)\n'

# %%
'''
files.download(avui+" "+societat+'-carrecs-empresia.xlsx')
'''
# Out:
# '\nfiles.download(avui+" "+societat+\'-carrecs-empresia.xlsx\')\n'

# %%
carrecs_hist = soup.find('table', {'id': 'EntidadRelacion'})
carrecs_hist = pd.read_html(str(carrecs_hist))[0]
carrecs_hist
# Out:
#                                               Entidad              Relación  \
# 0                           Aristizabal Larrauri Igor  Apod. Mancom./Solid.
# 1                           Aristizabal Larrauri Igor                 Apod.
# 2                                 Guzman Plaza Javier               Consej.
# 3                         TALDE GESTION S.G.E.C.R. SA               Consej.
# 4   Empresa De Promocio I Localitzacio Industrial ...               Consej.
# 5                              Fundacio Privada Alira               Consej.
# 6                                     Fundacio Ascamm               Consej.
# 7                           De La Mota Vazquez Xabier             Vicesecr.
# 8                                   MT GLOBAL GRUP SL               Consej.
# 9              MT GRUP DE GESTIO I DESENVOLUPAMENT SL               Consej.
# 10                                   Chico Roca Lluis  Apod. Mancom./Solid.
# 11                                 Lopez Lujan Javier  Apod. Mancom./Solid.
# 12                                   Chico Roca Lluis          Apod. Solid.
# 13                                 Lopez Lujan Javier          Apod. Solid.
# 14                        Lazaro Abaurre Luis Alberto          Apod. Solid.
# 15                  Armendia Fernandez De Viana Iñaki                 Secr.
# 16                                   Ruiz Pozueta Ane             Vicesecr.
# 17                             Izaguirre Paredes Kepa                 Secr.
# 18           Fundacion Tecnalia Research & Innovation               Consej.
# 19           Fundacion Tecnalia Research & Innovation               Presid.
# 20                                  Fundacion Inasmet               Consej.
# 21                                  Fundacion Inasmet               Presid.
# 22             MT GRUP DE GESTIO I DESENVOLUPAMENT SL               Presid.
# 23                                  Fundacion Inasmet                 Secr.
# 24                                 Lopez Lujan Javier                 Apod.
# 25                                   Chico Roca Lluis                 Apod.
# 26                                 Lopez Lujan Javier                 Apod.
# 27                        Lazaro Abaurre Luis Alberto                 Apod.
# 28                        Lazaro Abaurre Luis Alberto                 Apod.
#
#          Desde       Hasta
# 0   19/03/2014  05/04/2022
# 1   17/07/2013  05/04/2022
# 2   09/03/2021         NaN
# 3   03/02/2009  09/03/2021
# 4   29/12/2020         NaN
# 5   06/10/2015         NaN
# 6   03/02/2009  06/10/2015
# 7   07/06/2013  02/03/2015
# 8   07/08/2014         NaN
# 9   03/02/2009  07/08/2014
# 10  19/03/2014         NaN
# 11  19/03/2014         NaN
# 12  03/02/2009  19/03/2014
# 13  03/02/2009  19/03/2014
# 14  03/02/2009  19/03/2014
# 15  07/06/2013         NaN
# 16  09/11/2012  07/06/2013
# 17  03/02/2009  07/06/2013
# 18  22/08/2011         NaN
# 19  22/08/2011         NaN
# 20  03/02/2009  22/08/2011
# 21  03/02/2009  22/08/2011
# 22         NaN  03/02/2009
# 23         NaN  03/02/2009
# 24         NaN  03/02/2009
# 25         NaN  03/02/2009
# 26         NaN  03/02/2009
# 27         NaN  03/02/2009
# 28         NaN  03/02/2009

# %%
#!pip install xlsxwriter

# %%
import pandas as pd
import xlsxwriter
import datetime
from google.colab import files

avui = datetime.datetime.now()
avui = str(avui).split(" ")[0].replace("-", "")

# Exemple de tres taules diferents
df1 = pd.DataFrame(RM)
df2 = pd.DataFrame(carrecs)
df3 = pd.DataFrame(carrecs_hist)

# Crear l'arxiu d'Excel i afegir-hi les tres taules en pestanyes diferents
with pd.ExcelWriter(avui+" "+societat+'-empresia.xlsx', engine='xlsxwriter') as writer:
    df1.to_excel(writer, sheet_name='BORME', index=False)
    df2.to_excel(writer, sheet_name='Càrrecs_'+avui, index=False)
    df3.to_excel(writer, sheet_name='Càrrecs_històric', index=False)

files.download(avui+" "+societat+'-empresia.xlsx')
