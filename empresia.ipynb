# %%
societat = 'idiada-automotive-technology'

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.1.9-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.1.9

# %%
# %%shell
# sudo apt -y update
# sudo apt install -y wget curl unzip
# wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# dpkg -i libu2f-udev_1.1.4-1_all.deb
# wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# dpkg -i google-chrome-stable_current_amd64.deb
#
# wget -N https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/118.0.5993.70/linux64/chromedriver-linux64.zip -P /tmp/
# unzip -o /tmp/chromedriver-linux64.zip -d /tmp/
# chmod +x /tmp/chromedriver-linux64/chromedriver
# mv /tmp/chromedriver-linux64/chromedriver /usr/local/bin/chromedriver
# pip install selenium chromedriver_autoinstaller
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [671 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,746 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,800 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,436 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,334 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,723 kB]
# Fetched 8,944 kB in 2s (3,757 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 33 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# wget is already the newest version (1.21.2-2ubuntu1).
# curl is already the newest version (7.81.0-1ubuntu1.15).
# unzip is already the newest version (6.0-26ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.
# --2024-02-08 14:04:24--  http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 185.125.190.39, 91.189.91.81, 91.189.91.82, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|185.125.190.39|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3708 (3.6K) [application/x-debian-package]
# Saving to: ‘libu2f-udev_1.1.4-1_all.deb’
#
# libu2f-udev_1.1.4-1 100%[===================>]   3.62K  --.-KB/s    in 0s
#
# 2024-02-08 14:04:25 (302 MB/s) - ‘libu2f-udev_1.1.4-1_all.deb’ saved [3708/3708]
#
# Selecting previously unselected package libu2f-udev.
# (Reading database ... 121747 files and directories currently installed.)
# Preparing to unpack libu2f-udev_1.1.4-1_all.deb ...
# Unpacking libu2f-udev (1.1.4-1) ...
# Setting up libu2f-udev (1.1.4-1) ...
# --2024-02-08 14:04:26--  https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# Resolving dl.google.com (dl.google.com)... 173.194.196.91, 173.194.196.190, 173.194.196.136, ...
# Connecting to dl.google.com (dl.google.com)|173.194.196.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106437036 (102M) [application/x-debian-package]
# Saving to: ‘google-chrome-stable_current_amd64.deb’
#
# google-chrome-stabl 100%[===================>] 101.51M   239MB/s    in 0.4s
#
# 2024-02-08 14:04:26 (239 MB/s) - ‘google-chrome-stable_current_amd64.deb’ saved [106437036/106437036]
#
# Selecting previously unselected package google-chrome-stable.
# (Reading database ... 121751 files and directories currently installed.)
# Preparing to unpack google-chrome-stable_current_amd64.deb ...
# Unpacking google-chrome-stable (121.0.6167.160-1) ...
# dpkg: dependency problems prevent configuration of google-chrome-stable:
#  google-chrome-stable depends on libvulkan1; however:
#   Package libvulkan1 is not installed.
#
# dpkg: error processing package google-chrome-stable (--install):
#  dependency problems - leaving unconfigured
# Processing triggers for man-db (2.10.2-1) ...
# Errors were encountered while processing:
#  google-chrome-stable
# --2024-02-08 14:04:39--  https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/118.0.5993.70/linux64/chromedriver-linux64.zip
# Resolving edgedl.me.gvt1.com (edgedl.me.gvt1.com)... 34.104.35.123, 2600:1900:4110:86f::
# Connecting to edgedl.me.gvt1.com (edgedl.me.gvt1.com)|34.104.35.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8269742 (7.9M) [application/octet-stream]
# Saving to: ‘/tmp/chromedriver-linux64.zip’
#
# chromedriver-linux6 100%[===================>]   7.89M  --.-KB/s    in 0.1s
#
# 2024-02-08 14:04:39 (79.9 MB/s) - ‘/tmp/chromedriver-linux64.zip’ saved [8269742/8269742]
#
# Archive:  /tmp/chromedriver-linux64.zip
#   inflating: /tmp/chromedriver-linux64/LICENSE.chromedriver
#   inflating: /tmp/chromedriver-linux64/chromedriver
# Collecting selenium
#   Downloading selenium-4.17.2-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 12.6 MB/s eta 0:00:00
# Collecting chromedriver_autoinstaller
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.24.0-py3-none-any.whl (460 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 34.8 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.9.0)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from chromedriver_autoinstaller) (23.2)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.6)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, chromedriver_autoinstaller, wsproto, trio, trio-websocket, selenium
# Successfully installed chromedriver_autoinstaller-0.6.4 h11-0.14.0 outcome-1.3.0.post0 selenium-4.17.2 trio-0.24.0 trio-websocket-0.11.1 wsproto-1.2.0

# %%
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

from selenium import webdriver
import chromedriver_autoinstaller

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless') # this is must
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
chromedriver_autoinstaller.install()

driver = webdriver.Chrome(options=chrome_options)

# %%
import pandas as pd
import numpy as np
import time

# %%
#societat = 'forestal-catalana'

url = "https://www.empresia.es/empresa/"+societat+"/"

driver.get(url)

while True:
  try:
      # Executa JavaScript per fer clic al botó
      driver.execute_script("document.querySelector('#NextEventos > a').click();")
      print("S'ha fet clic al botó 'Ver más...'")

      # Espera fins que la pàgina es carregui (ajusta a les teves necessitats)
      time.sleep(5)

  except:
      print("Ja no surt el botó 'Ver más...'")
      break
# Out:
# S'ha fet clic al botó 'Ver más...'
# S'ha fet clic al botó 'Ver más...'
# Ja no surt el botó 'Ver más...'

# %%
from bs4 import BeautifulSoup
import re

RM = []

html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

event_contents = soup.find_all('div', {'class': 'event-content'})

for event_content in event_contents:
  link = event_content.find('a', {'class': 'newWin'})
  link = re.search(r"verPub\('(.+?)'", str(link)).group(1)
  full = re.search(r"H\s+(\w+)\s+(\d+)", str(event_content))
  if 'Empresa' in event_content.text:
    actual = "Nom antic o altra societat"
  else:
    actual = "Nom actual"
  RM.append([link, event_content.find_previous('time')['datetime'], " ".join(event_content.text.split()), (full[0] if full != None else full), actual])

# %%
import pandas as pd

pd.DataFrame(RM)
# Out:
#                                                     0           1  \
# 0   https://www.boe.es/borme/dias/2023/08/11/pdfs/...  2023-08-11
# 1   https://www.boe.es/borme/dias/2023/08/11/pdfs/...  2023-08-11
# 2   https://www.boe.es/borme/dias/2023/08/11/pdfs/...  2023-08-11
# 3   https://www.boe.es/borme/dias/2023/08/11/pdfs/...  2023-08-11
# 4   https://www.boe.es/borme/dias/2023/08/11/pdfs/...  2023-08-11
# ..                                                ...         ...
# 83  http://www.boe.es/borme/dias/2010/09/16/pdfs/B...  2010-09-16
# 84  http://www.boe.es/borme/dias/2009/11/17/pdfs/B...  2009-11-17
# 85  http://www.boe.es/borme/dias/2009/10/05/pdfs/B...  2009-10-05
# 86  http://www.boe.es/borme/dias/2009/05/08/pdfs/B...  2009-05-08
# 87  http://www.boe.es/borme/dias/2009/05/08/pdfs/B...  2009-05-08
#
#                                                     2          3  \
# 0   Ceses/Dimisiones.Publicación en el BORME de lo...  H T 18969
# 1   Nombramientos.Publicación en el BORME de los s...  H T 18969
# 2   Otros conceptos:Con fecha 25/01/2023 se inscri...  H T 18969
# 3   Ceses/Dimisiones. Con fecha 4 de agosto de 202...  H T 18969
# 4   Cancelaciones de oficio de nombramientos. Con ...  H T 18969
# ..                                                ...        ...
# 83  Depósito de cuentas anuales En agosto del 2010...       None
# 84  Reelecciones. Con fecha 5 de noviembre de 2009...  H T 18969
# 85  Depósito de cuentas anuales En agosto del 2009...       None
# 86  Ceses/Dimisiones.Publicación en el BORME de lo...  H T 18969
# 87  Nombramientos.Publicación en el BORME de los s...  H T 18969
#
#                              4
# 0   Nom antic o altra societat
# 1   Nom antic o altra societat
# 2                   Nom actual
# 3                   Nom actual
# 4                   Nom actual
# ..                         ...
# 83                  Nom actual
# 84                  Nom actual
# 85                  Nom actual
# 86                  Nom actual
# 87                  Nom actual
#
# [88 rows x 5 columns]

# %%
'''
import pandas as pd
pd.DataFrame(RM).to_excel(societat+'-empresia.xlsx', index=False)
'''
# Out:
# "\nimport pandas as pd\npd.DataFrame(RM).to_excel(societat+'-empresia.xlsx', index=False)\n"

# %%
'''
from google.colab import files
files.download(societat+'-empresia.xlsx')
'''
# Out:
# "\nfrom google.colab import files\nfiles.download(societat+'-empresia.xlsx')\n"

# %%
# buscar el div amb l'identificador 'organigrama'
organigrama_div = soup.find('div', {'id': 'organigrama'})

# buscar tots els elements 'li' dins del div amb l'identificador 'organigrama'

try:
  li_elements = organigrama_div.find_all('li')

  carrecs = []

# obtenir només el primer text de cada element 'li'
  for li in li_elements:
      # obtenir tots els continguts de l'element 'li'
      contents = li.contents

      # obtenir el primer text
      nom = str(contents[1].text).strip()
      carrec = str(contents[3]).strip()

      # imprimir el primer text
      carrecs.append([nom, carrec])

except:
  carrecs = []

# %%
pd.DataFrame(carrecs)
# Out:
#                                                     0          1
# 0                                Grasas Alsina Carles    Presid.
# 1   Agencia Per A La Competitivitat De L'empresa (...    Consej.
# 2                          APPLUS EUSKADI HOLDING  SL    Consej.
# 3                                Grasas Alsina Carles    Consej.
# 4                                    APPLUS ENERGY SL    Consej.
# 5                          APLLUS EUSKADI HOLDING  SL    Consej.
# 6        Agencia De Suport A L'empresa Catalana Accio    Consej.
# 7   Empresa De Promocio I Localitzacio Industrial ...    Consej.
# 8                         APPLUS ITEUVE TECHNOLOGY SL    Consej.
# 9                                  APPLUS SERVICES SA    Consej.
# 10                   APPLUS SERVICIOS TECNOLOGICOS SL    Consej.
# 11                                Argiles Malonda Eva      Secr.
# 12                            Contreras Castro Javier  Vicesecr.

# %%
import datetime

avui = datetime.datetime.now()
avui = str(avui).split(" ")[0].replace("-", "")
'''
pd.DataFrame(carrecs).to_excel(avui+" "+societat+'-carrecs-empresia.xlsx', index=False)
'''
# Out:
# '\npd.DataFrame(carrecs).to_excel(avui+" "+societat+\'-carrecs-empresia.xlsx\', index=False)\n'

# %%
'''
files.download(avui+" "+societat+'-carrecs-empresia.xlsx')
'''
# Out:
# '\nfiles.download(avui+" "+societat+\'-carrecs-empresia.xlsx\')\n'

# %%
carrecs_hist = soup.find('table', {'id': 'EntidadRelacion'})
carrecs_hist = pd.read_html(str(carrecs_hist))[0]
carrecs_hist
# Out:
#                                               Entidad      Relación  \
# 0                           APPLUS EUSKADI HOLDING SL       Consej.
# 1                                 Argiles Malonda Eva         Secr.
# 2   Agencia Per A La Competitivitat De L'empresa (...       Consej.
# 3                             Contreras Castro Javier     Vicesecr.
# 4                                Casals Noguer Angela         Secr.
# 5                            Farran Porte Josep Maria         Apod.
# 6                                Grasas Alsina Carles       Presid.
# 7                                Grasas Alsina Carles       Consej.
# 8                                  APPLUS SERVICES SA       Presid.
# 9                                Grasas Alsina Carles  Dir. General
# 10                                   APPLUS ENERGY SL       Consej.
# 11                          CATALUNYACAIXA CAPITAL SA       Consej.
# 12                   APPLUS SERVICIOS TECNOLOGICOS SL  Consej. Del.
# 13   INVERCARTERA SA AHORA CATALUNYACAIXA CAPITAL SAU       Consej.
# 14                          APLLUS EUSKADI HOLDING SL       Consej.
# 15                                   Pardo Rojo Mario       Consej.
# 16  Empresa De Promocio I Localitzacio Industrial ...       Consej.
# 17       Agencia De Suport A L'empresa Catalana Accio       Consej.
# 18                                   Roig Juan Albert       Consej.
# 19                                     Jane Bru Jordi     Vicesecr.
# 20                        APPLUS ITEUVE TECHNOLOGY SL       Consej.
# 21                                  Soy Casals Antoni       Consej.
# 22                              Clar Guevara Joan Pau       Consej.
# 23                   APPLUS SERVICIOS TECNOLOGICOS SL       Consej.
# 24                                 APPLUS SERVICES SA       Consej.
# 25                      Auguets Pratsobrerroca Xavier       Consej.
# 26                                   Amigo Casas Joan       Consej.
# 27                                  Lluch Zanon Jorge       Consej.
# 28                      Rodriguez Martin Manuel Angel       Consej.
# 29                               Grasas Alsina Carles  Consej. Del.
# 30                                         Ver más...    Ver más...
#
#                                      Entidad/Relación       Desde       Hasta
# 0                   APPLUS EUSKADI HOLDING SL Consej.  04/08/2023         NaN
# 1                           Argiles Malonda Eva Secr.  04/08/2023         NaN
# 2   Agencia Per A La Competitivitat De L'empresa (...  04/08/2023         NaN
# 3                   Contreras Castro Javier Vicesecr.  04/08/2023         NaN
# 4                          Casals Noguer Angela Secr.         NaN  04/08/2023
# 5                      Farran Porte Josep Maria Apod.  13/07/2020         NaN
# 6                        Grasas Alsina Carles Presid.  13/07/2020         NaN
# 7                        Grasas Alsina Carles Consej.  13/07/2020         NaN
# 8                          APPLUS SERVICES SA Presid.  28/04/2009  13/07/2020
# 9                   Grasas Alsina Carles Dir. General         NaN  13/07/2020
# 10                           APPLUS ENERGY SL Consej.  29/12/2016         NaN
# 11                  CATALUNYACAIXA CAPITAL SA Consej.  28/04/2009  29/12/2016
# 12      APPLUS SERVICIOS TECNOLOGICOS SL Consej. Del.  28/04/2009  13/06/2014
# 13  INVERCARTERA SA AHORA CATALUNYACAIXA CAPITAL S...         NaN  13/06/2014
# 14                  APLLUS EUSKADI HOLDING SL Consej.  11/01/2013         NaN
# 15                           Pardo Rojo Mario Consej.         NaN  11/01/2013
# 16  Empresa De Promocio I Localitzacio Industrial ...  05/01/2012         NaN
# 17  Agencia De Suport A L'empresa Catalana Accio C...  05/01/2012         NaN
# 18                           Roig Juan Albert Consej.  17/01/2011  05/01/2012
# 19                           Jane Bru Jordi Vicesecr.         NaN  13/09/2011
# 20                APPLUS ITEUVE TECHNOLOGY SL Consej.  21/07/2011         NaN
# 21                          Soy Casals Antoni Consej.         NaN  21/07/2011
# 22                      Clar Guevara Joan Pau Consej.         NaN  17/01/2011
# 23           APPLUS SERVICIOS TECNOLOGICOS SL Consej.  28/04/2009         NaN
# 24                         APPLUS SERVICES SA Consej.  28/04/2009         NaN
# 25              Auguets Pratsobrerroca Xavier Consej.         NaN  28/04/2009
# 26                           Amigo Casas Joan Consej.         NaN  28/04/2009
# 27                          Lluch Zanon Jorge Consej.         NaN  28/04/2009
# 28              Rodriguez Martin Manuel Angel Consej.         NaN  28/04/2009
# 29                  Grasas Alsina Carles Consej. Del.         NaN  28/04/2009
# 30                                         Ver más...  Ver más...         NaN

# %%
#!pip install xlsxwriter

# %%
import pandas as pd
import xlsxwriter
import datetime
from google.colab import files

avui = datetime.datetime.now()
avui = str(avui).split(" ")[0].replace("-", "")

# Exemple de tres taules diferents
df1 = pd.DataFrame(RM)
df2 = pd.DataFrame(carrecs)
df3 = pd.DataFrame(carrecs_hist)

# Crear l'arxiu d'Excel i afegir-hi les tres taules en pestanyes diferents
with pd.ExcelWriter(avui+" "+societat+'-empresia.xlsx', engine='xlsxwriter') as writer:
    df1.to_excel(writer, sheet_name='BORME', index=False)
    df2.to_excel(writer, sheet_name='Càrrecs_'+avui, index=False)
    df3.to_excel(writer, sheet_name='Càrrecs_històric', index=False)

files.download(avui+" "+societat+'-empresia.xlsx')
